# %% [markdown]
# # Object Extraction (Racks) for Semantic Segmentation Neural Networks

# %% [markdown]
# ### The following code utilizes the PointBluePython (LabelPC) library to process facilities and extract their racks into text files.
#
# The code reads from a facilities directory `facilties_rootdir` containing sub directories of the facilities names and each subdirectory containing its facility JSON and LAS or LAZ file: `facilties_rootdir/Facility_Name/...`
#
# The text files have the x, y, z, r, g, b (float, float, float, int, int, int) data structure separated by empty spaces. Each line represents one of the randomly chosen (number configurable) points.
#
# #### The structure of the created dataset files is as follows
#
# `facilties_rootdir/dataOutput/FacilityName_N/Annotations/...` Where "N" represents the facility number.
#
# The facility is divided into text-like pointcloud files of all of its racks (racks classes) and a general file called clutter for everything else.
#
# This data can be later fed to the semantic segmentation neural network on [Pointnet2 Neural Network](https://github.com/marcofariasmx/Pointnet_Warehouse_pytorch)

# %% [markdown]
# **Note:** Please make sure you are running this script under LabelPC's environment to ensure compatibility with its library

# %%
import sys
import os
from collections import defaultdict

# %%
sys.path.append('../')

# %%
from WarehouseDataStructures.Scan import Scan
from Utils.full_file_normals_calculation import normals_calculation

# %% [markdown]
# ### Execute the code in charge of reading facilities' data
#
# #### Read over the facilities (assumes all facilities with their respective files and file structure are in a single directory

# %%
#facilities_path = './facilities_rootdir/'
facilities_path = r'C:\Users\M0x1\Downloads\FacilitiesX10New/'

facilities_list = os.listdir(facilities_path)

print(facilities_list)
# Out:
# ['142728079488_US - CA, Los Angeles - Los Palos (Big Bear)', '143039459344_US - NJ, Logan Township - Crossroads', '153924853363_US - TX, El Paso - Railroad', '194913221226_CAN - AB, Calgary - 5555 78th Ave SE (Calgary Foothills)', '194915139195_CAN - AB, Lethbridge - 585 41st St North', '194916756196_CAN - AB, Edmonton - 12536 62 St (Northlands)', '196524033787_CAN - MB, Winnipeg - 200 Dawson Rd N', '196524856938_CAN - QC, Montreal - 5757 Chemin St. Francois', '196527723206_CAN - ON, Brampton - 107 Walker Dr', '196527859613_CAN - QC, Saint-Laurent - 6100 Côte de Liesse']

# %%
json_filespath = []
for annotated_facility in facilities_list:
    files_names = os.listdir(facilities_path + annotated_facility)
    for file_name in files_names:
        if file_name.endswith('.json'):
            json_filespath.append(facilities_path + annotated_facility + '/' + file_name)
    
print(json_filespath)
# Out:
# ['C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/142728079488_US - CA, Los Angeles - Los Palos (Big Bear)/US - CA, Los Angeles (Big Bear) - Los Palos.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/143039459344_US - NJ, Logan Township - Crossroads/loganTownship_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/153924853363_US - TX, El Paso - Railroad/railroad_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/194913221226_CAN - AB, Calgary - 5555 78th Ave SE (Calgary Foothills)/FoothHills_Calgary_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/194915139195_CAN - AB, Lethbridge - 585 41st St North/Lethbridge_1cm_nomals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/194916756196_CAN - AB, Edmonton - 12536 62 St (Northlands)/edmontonNorth_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/196524033787_CAN - MB, Winnipeg - 200 Dawson Rd N/Dawson_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/196524856938_CAN - QC, Montreal - 5757 Chemin St. Francois/StFrancois_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/196527723206_CAN - ON, Brampton - 107 Walker Dr/bramptonWalker_1cm_normals.json', 'C:\\Users\\M0x1\\Downloads\\FacilitiesX10New/196527859613_CAN - QC, Saint-Laurent - 6100 Côte de Liesse/CoteDeLiesse_normals_1cm.json']

# %%
def get_rack_bounding_box(rack, tolerance = 0):
    """
    Method that gets a rack object and an extra tolerance number to return the bounding box coordenates of the rack.
    
    
    Parameters
    -------------
    rack: BaseRack
        rack object to get the bounding box for
    tolerance: float
        tolerance number for the bounding box in meters.
        e.g: .15 = extra 15 centimeters to each side of the bounding box.
        
    Return
    -------------
    xmin, xmax, ymin, ymax, zmin, zmax: float
        The coordinates of the rack's bounding box.
    """
    xmin = min(vertex[0] for vertex in rack.vertices)
    xmax = max(vertex[0] for vertex in rack.vertices)
    ymin = min(vertex[1] for vertex in rack.vertices)
    ymax = max(vertex[1] for vertex in rack.vertices)
    try:
        zmin = rack.base_bottoms[0][0][0] #rack.bottom_height
    except:
        zmin = 0
    zmax = sum(rack.base_heights[0][0]) #rack.top_height
    if zmax == 0:
        zmax = sum(rack.base_bottoms[0][0])
    if zmax == 0:
        zmax = 3
    if zmax < zmin:
        zmax = zmin
        zmin = 0
    
        
    #return xmin, xmax, ymin, ymax, zmin, zmax
    return xmin + tolerance, xmax + tolerance, ymin + tolerance, ymax + tolerance, zmin + tolerance, zmax + tolerance

# %%
def map_to_255(value):
    """
    Maps a floating-point value from the range 0 to 1 to the range 0 to 255.
    
    Parameters
    -------------
    value: float
        value to map
        
    Return
    -------------
    mapped_value: int
        Number from 0 to 255.
    """
    scaled_value = value * 255
    mapped_value = int(scaled_value)
    return mapped_value

# %%
def calculate_normals(scan, k=100, r=.15):
    """
    Calculates the normals for the currently-selected scan.

    Calculate the normal direction for each point currently loaded in the
    current scan (defined by :func:`~MainWindow.cur_scan` property) and
    store them in the rgb columns of the point cloud DataFrame. In
    addition to the normals, also calculate the local neighborhood
    density and curvature values and store them in the "class" and
    "intensity" columns respectively.

    k = neighboors
    r = radious
    """
    print("Calculating normals for scan file...")
    scan.point_cloud.points.iloc[:]['user_data'] = scan.point_cloud.points.iloc[:][
                                                                ['r', 'g', 'b']].sum(axis=1) / 3.0
    normals, curvature, density = normals_calculation(scan.point_cloud.xyz, k, r)
    scan.point_cloud.points.loc[:, 'r'] = normals[:, 0]
    scan.point_cloud.points.loc[:, 'g'] = normals[:, 1]
    scan.point_cloud.points.loc[:, 'b'] = normals[:, 2]
    scan.point_cloud.points.loc[:, 'class'] = curvature
    scan.point_cloud.points.loc[:, 'intensity'] = density
    print("Normals calculation done!")

# %% [markdown]
# #### Create dictionaries and methods to store the gathered information

# %%
global_racks_dict = {}
facility_racks_dict = {}

# %%
# Function to add objects to the inner dictionary
def add_object(inner_dict, obj_type, obj):
    if obj_type in inner_dict:
        inner_dict[obj_type].append(obj)  # If the object type exists, add the object to the existing list
    else:
        inner_dict[obj_type] = [obj]  # If the object type doesn't exist, create a new list with the object

# Function to add facilities to the main dictionary
def add_facility(facility_dict, facility_name):
    facility_dict[facility_name] = {}  # Create an empty dictionary for the facility

# %% [markdown]
# #### Execute loop to iterate over every facility and extract its data

# %% [markdown]
# Points to load for each facility

# %%
num_points_to_load = 1000000 #20000000

# %%
for index, facility_file in enumerate(json_filespath):
    scan = Scan(filename=facility_file, n_points=num_points_to_load)
    shapes = scan.shapes
    
    # Add facility to the facility racks dict
    add_facility(facility_racks_dict, facilities_list[index])
    
    #Calculate normals for scan file
    calculate_normals(scan)

    # Create a dictionary of the facility's racks
    racks_dict = {}
    for rack in shapes.racks:
        if rack.label in racks_dict:
            racks_dict[rack.label].append(rack)
        else:
            racks_dict[rack.label] = [rack]
            
        if rack.label in global_racks_dict:
            global_racks_dict[rack.label].append(rack)
        else:
            global_racks_dict[rack.label] = [rack]
            
    facility_racks_count = 0

    for value in racks_dict.values():
        if isinstance(value, list):
            facility_racks_count += len(value)
        else:
            facility_racks_count += 1

    print("Facility's rack count: ", facility_racks_count)
    
    original_point_cloud_df = scan.point_cloud.points
    point_cloud_df = original_point_cloud_df.copy()
    
    directory = facilities_path + 'dataOutput/' + facilities_list[index] + '_' + str(index+1)
    
    if not os.path.exists(directory + '/Annotations'):
        os.makedirs(directory + '/Annotations')
        
    rack_counter = 1
    
    for key in racks_dict.keys():
        for idx, rack in enumerate(racks_dict[key]):
            xmin, xmax, ymin, ymax, zmin, zmax = get_rack_bounding_box(rack, tolerance=0)

            
            # Create a new DataFrame of the racks points within the bounding box limits
            bounding_box_df = point_cloud_df[(point_cloud_df['x'] >= xmin) & (point_cloud_df['x'] <= xmax) &
                                         (point_cloud_df['y'] >= ymin) & (point_cloud_df['y'] <= ymax) &
                                         (point_cloud_df['z'] >= zmin) & (point_cloud_df['z'] <= zmax)].copy()
            
            if len(bounding_box_df.index) >= 200: #if less than 200 points then the annotation for that rack is not useful for training purposes, discard it
                # Write the output text file
                obj_name = str(rack.label).replace("_", "-" )
                output_text_file = obj_name +'_'+ str(idx+1) + ".txt"
                with open(directory + '/Annotations/' + output_text_file, 'w') as file:
                    for _, row in bounding_box_df.iterrows():
                        file.write("%f %f %f %d %d %d\n" % (row['x'], row['y'], row['z'], map_to_255(row['r']), map_to_255(row['g']), map_to_255(row['b'])))

                # Add rack object to the dict of facilities and their respective racks (dict of dict of lists)
                add_object(facility_racks_dict[facilities_list[index]], rack.label, rack)
            
            print("Saved: Facility ", str(index+1), " / ", str(len(json_filespath)), " rack ", str(rack_counter), "/", str(facility_racks_count))
            rack_counter += 1
            
            # Get the indices of rows to be removed
            indices_to_remove = bounding_box_df.index

            # Remove the rows from the original DataFrame
            point_cloud_df = point_cloud_df.drop(indices_to_remove)
            
            print("Points left: ", len(point_cloud_df.index))
            
    # Create clutter class pointcloud txt file
    output_text_file = 'clutter' + '_' + str(1) + ".txt"
    with open(directory + '/Annotations/' + output_text_file, 'w') as file:
        for _, row in point_cloud_df.iterrows():
            file.write("%f %f %f %d %d %d\n" % (row['x'], row['y'], row['z'], map_to_255(row['r']), map_to_255(row['g']), map_to_255(row['b'])))
    
    # Create general pointcloud txt file
    output_text_file = 'All-points-facility' + '_' + str(index+1) + ".txt"
    with open(directory + '/' + output_text_file, 'w') as file:
        for _, row in original_point_cloud_df.iterrows():
            file.write("%f %f %f %d %d %d\n" % (row['x'], row['y'], row['z'], map_to_255(row['r']), map_to_255(row['g']), map_to_255(row['b'])))
    
    print("Saved general facility file")
# Out:
# Successful points load of  US - CA, Los Angeles (Big Bear) - Los Palos.laz
# 07-23-23 15:01:38 - [WARNING] - This JSON file (US - CA, Los Angeles (Big Bear) - Los Palos) may be incompatible with current labelpc. Version in file: 11.4.0, current version: 12.5.0 (Scan.py:877)
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  86
# Saved: Facility  1  /  10  rack  1 / 86
# Points left:  996041
# Saved: Facility  1  /  10  rack  2 / 86
# Points left:  990627
# Saved: Facility  1  /  10  rack  3 / 86
# Points left:  986289
# Saved: Facility  1  /  10  rack  4 / 86
# Points left:  979715
# Saved: Facility  1  /  10  rack  5 / 86
# Points left:  977962
# Saved: Facility  1  /  10  rack  6 / 86
# Points left:  972220
# Saved: Facility  1  /  10  rack  7 / 86
# Points left:  969053
# Saved: Facility  1  /  10  rack  8 / 86
# Points left:  960907
# Saved: Facility  1  /  10  rack  9 / 86
# Points left:  957132
# Saved: Facility  1  /  10  rack  10 / 86
# Points left:  951517
# Saved: Facility  1  /  10  rack  11 / 86
# Points left:  948206
# Saved: Facility  1  /  10  rack  12 / 86
# Points left:  944333
# Saved: Facility  1  /  10  rack  13 / 86
# Points left:  939013
# Saved: Facility  1  /  10  rack  14 / 86
# Points left:  935736
# Saved: Facility  1  /  10  rack  15 / 86
# Points left:  929910
# Saved: Facility  1  /  10  rack  16 / 86
# Points left:  923601
# Saved: Facility  1  /  10  rack  17 / 86
# Points left:  915773
# Saved: Facility  1  /  10  rack  18 / 86
# Points left:  912332
# Saved: Facility  1  /  10  rack  19 / 86
# Points left:  906626
# Saved: Facility  1  /  10  rack  20 / 86
# Points left:  897800
# Saved: Facility  1  /  10  rack  21 / 86
# Points left:  892790
# Saved: Facility  1  /  10  rack  22 / 86
# Points left:  885784
# Saved: Facility  1  /  10  rack  23 / 86
# Points left:  878859
# Saved: Facility  1  /  10  rack  24 / 86
# Points left:  872549
# Saved: Facility  1  /  10  rack  25 / 86
# Points left:  867595
# Saved: Facility  1  /  10  rack  26 / 86
# Points left:  861523
# Saved: Facility  1  /  10  rack  27 / 86
# Points left:  854282
# Saved: Facility  1  /  10  rack  28 / 86
# Points left:  847091
# Saved: Facility  1  /  10  rack  29 / 86
# Points left:  839648
# Saved: Facility  1  /  10  rack  30 / 86
# Points left:  833822
# Saved: Facility  1  /  10  rack  31 / 86
# Points left:  828778
# Saved: Facility  1  /  10  rack  32 / 86
# Points left:  823290
# Saved: Facility  1  /  10  rack  33 / 86
# Points left:  816256
# Saved: Facility  1  /  10  rack  34 / 86
# Points left:  811142
# Saved: Facility  1  /  10  rack  35 / 86
# Points left:  806175
# Saved: Facility  1  /  10  rack  36 / 86
# Points left:  800125
# Saved: Facility  1  /  10  rack  37 / 86
# Points left:  794395
# Saved: Facility  1  /  10  rack  38 / 86
# Points left:  784323
# Saved: Facility  1  /  10  rack  39 / 86
# Points left:  778608
# Saved: Facility  1  /  10  rack  40 / 86
# Points left:  771799
# Saved: Facility  1  /  10  rack  41 / 86
# Points left:  762408
# Saved: Facility  1  /  10  rack  42 / 86
# Points left:  755489
# Saved: Facility  1  /  10  rack  43 / 86
# Points left:  748112
# Saved: Facility  1  /  10  rack  44 / 86
# Points left:  743000
# Saved: Facility  1  /  10  rack  45 / 86
# Points left:  737482
# Saved: Facility  1  /  10  rack  46 / 86
# Points left:  731849
# Saved: Facility  1  /  10  rack  47 / 86
# Points left:  725150
# Saved: Facility  1  /  10  rack  48 / 86
# Points left:  721149
# Saved: Facility  1  /  10  rack  49 / 86
# Points left:  716090
# Saved: Facility  1  /  10  rack  50 / 86
# Points left:  712792
# Saved: Facility  1  /  10  rack  51 / 86
# Points left:  707523
# Saved: Facility  1  /  10  rack  52 / 86
# Points left:  700946
# Saved: Facility  1  /  10  rack  53 / 86
# Points left:  694022
# Saved: Facility  1  /  10  rack  54 / 86
# Points left:  686974
# Saved: Facility  1  /  10  rack  55 / 86
# Points left:  680560
# Saved: Facility  1  /  10  rack  56 / 86
# Points left:  672145
# Saved: Facility  1  /  10  rack  57 / 86
# Points left:  667297
# Saved: Facility  1  /  10  rack  58 / 86
# Points left:  661259
# Saved: Facility  1  /  10  rack  59 / 86
# Points left:  657672
# Saved: Facility  1  /  10  rack  60 / 86
# Points left:  651440
# Saved: Facility  1  /  10  rack  61 / 86
# Points left:  646670
# Saved: Facility  1  /  10  rack  62 / 86
# Points left:  640466
# Saved: Facility  1  /  10  rack  63 / 86
# Points left:  635755
# Saved: Facility  1  /  10  rack  64 / 86
# Points left:  629143
# Saved: Facility  1  /  10  rack  65 / 86
# Points left:  626023
# Saved: Facility  1  /  10  rack  66 / 86
# Points left:  622915
# Saved: Facility  1  /  10  rack  67 / 86
# Points left:  615819
# Saved: Facility  1  /  10  rack  68 / 86
# Points left:  610867
# Saved: Facility  1  /  10  rack  69 / 86
# Points left:  606917
# Saved: Facility  1  /  10  rack  70 / 86
# Points left:  599180
# Saved: Facility  1  /  10  rack  71 / 86
# Points left:  593494
# Saved: Facility  1  /  10  rack  72 / 86
# Points left:  588139
# Saved: Facility  1  /  10  rack  73 / 86
# Points left:  584295
# Saved: Facility  1  /  10  rack  74 / 86
# Points left:  579458
# Saved: Facility  1  /  10  rack  75 / 86
# Points left:  573681
# Saved: Facility  1  /  10  rack  76 / 86
# Points left:  567295
# Saved: Facility  1  /  10  rack  77 / 86
# Points left:  558159
# Saved: Facility  1  /  10  rack  78 / 86
# Points left:  552499
# Saved: Facility  1  /  10  rack  79 / 86
# Points left:  547174
# Saved: Facility  1  /  10  rack  80 / 86
# Points left:  539959
# Saved: Facility  1  /  10  rack  81 / 86
# Points left:  533806
# Saved: Facility  1  /  10  rack  82 / 86
# Points left:  529176
# Saved: Facility  1  /  10  rack  83 / 86
# Points left:  522637
# Saved: Facility  1  /  10  rack  84 / 86
# Points left:  516677
# Saved: Facility  1  /  10  rack  85 / 86
# Points left:  511298
# Saved: Facility  1  /  10  rack  86 / 86
# Points left:  504349
# Saved general facility file
# Successful points load of  loganTownship_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  52
# Saved: Facility  2  /  10  rack  1 / 52
# Points left:  1000685
# Saved: Facility  2  /  10  rack  2 / 52
# Points left:  993612
# Saved: Facility  2  /  10  rack  3 / 52
# Points left:  986277
# Saved: Facility  2  /  10  rack  4 / 52
# Points left:  977797
# Saved: Facility  2  /  10  rack  5 / 52
# Points left:  967833
# Saved: Facility  2  /  10  rack  6 / 52
# Points left:  960710
# Saved: Facility  2  /  10  rack  7 / 52
# Points left:  953976
# Saved: Facility  2  /  10  rack  8 / 52
# Points left:  945277
# Saved: Facility  2  /  10  rack  9 / 52
# Points left:  937863
# Saved: Facility  2  /  10  rack  10 / 52
# Points left:  930461
# Saved: Facility  2  /  10  rack  11 / 52
# Points left:  923387
# Saved: Facility  2  /  10  rack  12 / 52
# Points left:  916818
# Saved: Facility  2  /  10  rack  13 / 52
# Points left:  910238
# Saved: Facility  2  /  10  rack  14 / 52
# Points left:  903369
# Saved: Facility  2  /  10  rack  15 / 52
# Points left:  896106
# Saved: Facility  2  /  10  rack  16 / 52
# Points left:  888366
# Saved: Facility  2  /  10  rack  17 / 52
# Points left:  880046
# Saved: Facility  2  /  10  rack  18 / 52
# Points left:  872284
# Saved: Facility  2  /  10  rack  19 / 52
# Points left:  865861
# Saved: Facility  2  /  10  rack  20 / 52
# Points left:  859123
# Saved: Facility  2  /  10  rack  21 / 52
# Points left:  852229
# Saved: Facility  2  /  10  rack  22 / 52
# Points left:  843653
# Saved: Facility  2  /  10  rack  23 / 52
# Points left:  836669
# Saved: Facility  2  /  10  rack  24 / 52
# Points left:  827963
# Saved: Facility  2  /  10  rack  25 / 52
# Points left:  820854
# Saved: Facility  2  /  10  rack  26 / 52
# Points left:  813516
# Saved: Facility  2  /  10  rack  27 / 52
# Points left:  806713
# Saved: Facility  2  /  10  rack  28 / 52
# Points left:  799435
# Saved: Facility  2  /  10  rack  29 / 52
# Points left:  792157
# Saved: Facility  2  /  10  rack  30 / 52
# Points left:  786928
# Saved: Facility  2  /  10  rack  31 / 52
# Points left:  780017
# Saved: Facility  2  /  10  rack  32 / 52
# Points left:  772888
# Saved: Facility  2  /  10  rack  33 / 52
# Points left:  765258
# Saved: Facility  2  /  10  rack  34 / 52
# Points left:  756990
# Saved: Facility  2  /  10  rack  35 / 52
# Points left:  749723
# Saved: Facility  2  /  10  rack  36 / 52
# Points left:  742587
# Saved: Facility  2  /  10  rack  37 / 52
# Points left:  735596
# Saved: Facility  2  /  10  rack  38 / 52
# Points left:  728265
# Saved: Facility  2  /  10  rack  39 / 52
# Points left:  721048
# Saved: Facility  2  /  10  rack  40 / 52
# Points left:  714077
# Saved: Facility  2  /  10  rack  41 / 52
# Points left:  707536
# Saved: Facility  2  /  10  rack  42 / 52
# Points left:  701303
# Saved: Facility  2  /  10  rack  43 / 52
# Points left:  694278
# Saved: Facility  2  /  10  rack  44 / 52
# Points left:  687946
# Saved: Facility  2  /  10  rack  45 / 52
# Points left:  680413
# Saved: Facility  2  /  10  rack  46 / 52
# Points left:  672363
# Saved: Facility  2  /  10  rack  47 / 52
# Points left:  664334
# Saved: Facility  2  /  10  rack  48 / 52
# Points left:  656675
# Saved: Facility  2  /  10  rack  49 / 52
# Points left:  649075
# Saved: Facility  2  /  10  rack  50 / 52
# Points left:  639242
# Saved: Facility  2  /  10  rack  51 / 52
# Points left:  631738
# Saved: Facility  2  /  10  rack  52 / 52
# Points left:  624015
# Saved general facility file
# Successful points load of  railroad_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  97
# Saved: Facility  3  /  10  rack  1 / 97
# Points left:  1000662
# Saved: Facility  3  /  10  rack  2 / 97
# Points left:  1000662
# Saved: Facility  3  /  10  rack  3 / 97
# Points left:  1000502
# Saved: Facility  3  /  10  rack  4 / 97
# Points left:  996484
# Saved: Facility  3  /  10  rack  5 / 97
# Points left:  994189
# Saved: Facility  3  /  10  rack  6 / 97
# Points left:  991818
# Saved: Facility  3  /  10  rack  7 / 97
# Points left:  987443
# Saved: Facility  3  /  10  rack  8 / 97
# Points left:  987443
# Saved: Facility  3  /  10  rack  9 / 97
# Points left:  987443
# Saved: Facility  3  /  10  rack  10 / 97
# Points left:  972874
# Saved: Facility  3  /  10  rack  11 / 97
# Points left:  972404
# Saved: Facility  3  /  10  rack  12 / 97
# Points left:  956573
# Saved: Facility  3  /  10  rack  13 / 97
# Points left:  953351
# Saved: Facility  3  /  10  rack  14 / 97
# Points left:  953351
# Saved: Facility  3  /  10  rack  15 / 97
# Points left:  946327
# Saved: Facility  3  /  10  rack  16 / 97
# Points left:  945540
# Saved: Facility  3  /  10  rack  17 / 97
# Points left:  944709
# Saved: Facility  3  /  10  rack  18 / 97
# Points left:  944709
# Saved: Facility  3  /  10  rack  19 / 97
# Points left:  943026
# Saved: Facility  3  /  10  rack  20 / 97
# Points left:  942727
# Saved: Facility  3  /  10  rack  21 / 97
# Points left:  942214
# Saved: Facility  3  /  10  rack  22 / 97
# Points left:  941530
# Saved: Facility  3  /  10  rack  23 / 97
# Points left:  941530
# Saved: Facility  3  /  10  rack  24 / 97
# Points left:  940510
# Saved: Facility  3  /  10  rack  25 / 97
# Points left:  938382
# Saved: Facility  3  /  10  rack  26 / 97
# Points left:  936412
# Saved: Facility  3  /  10  rack  27 / 97
# Points left:  936412
# Saved: Facility  3  /  10  rack  28 / 97
# Points left:  935470
# Saved: Facility  3  /  10  rack  29 / 97
# Points left:  935470
# Saved: Facility  3  /  10  rack  30 / 97
# Points left:  931937
# Saved: Facility  3  /  10  rack  31 / 97
# Points left:  923008
# Saved: Facility  3  /  10  rack  32 / 97
# Points left:  919953
# Saved: Facility  3  /  10  rack  33 / 97
# Points left:  919570
# Saved: Facility  3  /  10  rack  34 / 97
# Points left:  917487
# Saved: Facility  3  /  10  rack  35 / 97
# Points left:  914812
# Saved: Facility  3  /  10  rack  36 / 97
# Points left:  914208
# Saved: Facility  3  /  10  rack  37 / 97
# Points left:  913749
# Saved: Facility  3  /  10  rack  38 / 97
# Points left:  912601
# Saved: Facility  3  /  10  rack  39 / 97
# Points left:  908045
# Saved: Facility  3  /  10  rack  40 / 97
# Points left:  905777
# Saved: Facility  3  /  10  rack  41 / 97
# Points left:  904758
# Saved: Facility  3  /  10  rack  42 / 97
# Points left:  902320
# Saved: Facility  3  /  10  rack  43 / 97
# Points left:  901538
# Saved: Facility  3  /  10  rack  44 / 97
# Points left:  896157
# Saved: Facility  3  /  10  rack  45 / 97
# Points left:  893672
# Saved: Facility  3  /  10  rack  46 / 97
# Points left:  891503
# Saved: Facility  3  /  10  rack  47 / 97
# Points left:  891365
# Saved: Facility  3  /  10  rack  48 / 97
# Points left:  889633
# Saved: Facility  3  /  10  rack  49 / 97
# Points left:  889058
# Saved: Facility  3  /  10  rack  50 / 97
# Points left:  887658
# Saved: Facility  3  /  10  rack  51 / 97
# Points left:  887305
# Saved: Facility  3  /  10  rack  52 / 97
# Points left:  884897
# Saved: Facility  3  /  10  rack  53 / 97
# Points left:  883954
# Saved: Facility  3  /  10  rack  54 / 97
# Points left:  882337
# Saved: Facility  3  /  10  rack  55 / 97
# Points left:  881956
# Saved: Facility  3  /  10  rack  56 / 97
# Points left:  881401
# Saved: Facility  3  /  10  rack  57 / 97
# Points left:  881369
# Saved: Facility  3  /  10  rack  58 / 97
# Points left:  881352
# Saved: Facility  3  /  10  rack  59 / 97
# Points left:  880468
# Saved: Facility  3  /  10  rack  60 / 97
# Points left:  880309
# Saved: Facility  3  /  10  rack  61 / 97
# Points left:  877396
# Saved: Facility  3  /  10  rack  62 / 97
# Points left:  873217
# Saved: Facility  3  /  10  rack  63 / 97
# Points left:  872372
# Saved: Facility  3  /  10  rack  64 / 97
# Points left:  871489
# Saved: Facility  3  /  10  rack  65 / 97
# Points left:  867833
# Saved: Facility  3  /  10  rack  66 / 97
# Points left:  866617
# Saved: Facility  3  /  10  rack  67 / 97
# Points left:  865953
# Saved: Facility  3  /  10  rack  68 / 97
# Points left:  864792
# Saved: Facility  3  /  10  rack  69 / 97
# Points left:  864354
# Saved: Facility  3  /  10  rack  70 / 97
# Points left:  862901
# Saved: Facility  3  /  10  rack  71 / 97
# Points left:  861576
# Saved: Facility  3  /  10  rack  72 / 97
# Points left:  860887
# Saved: Facility  3  /  10  rack  73 / 97
# Points left:  859085
# Saved: Facility  3  /  10  rack  74 / 97
# Points left:  858103
# Saved: Facility  3  /  10  rack  75 / 97
# Points left:  858103
# Saved: Facility  3  /  10  rack  76 / 97
# Points left:  855801
# Saved: Facility  3  /  10  rack  77 / 97
# Points left:  855766
# Saved: Facility  3  /  10  rack  78 / 97
# Points left:  855114
# Saved: Facility  3  /  10  rack  79 / 97
# Points left:  851972
# Saved: Facility  3  /  10  rack  80 / 97
# Points left:  848368
# Saved: Facility  3  /  10  rack  81 / 97
# Points left:  847840
# Saved: Facility  3  /  10  rack  82 / 97
# Points left:  842648
# Saved: Facility  3  /  10  rack  83 / 97
# Points left:  839762
# Saved: Facility  3  /  10  rack  84 / 97
# Points left:  839740
# Saved: Facility  3  /  10  rack  85 / 97
# Points left:  838968
# Saved: Facility  3  /  10  rack  86 / 97
# Points left:  838076
# Saved: Facility  3  /  10  rack  87 / 97
# Points left:  837968
# Saved: Facility  3  /  10  rack  88 / 97
# Points left:  837120
# Saved: Facility  3  /  10  rack  89 / 97
# Points left:  835893
# Saved: Facility  3  /  10  rack  90 / 97
# Points left:  834978
# Saved: Facility  3  /  10  rack  91 / 97
# Points left:  834673
# Saved: Facility  3  /  10  rack  92 / 97
# Points left:  831771
# Saved: Facility  3  /  10  rack  93 / 97
# Points left:  828678
# Saved: Facility  3  /  10  rack  94 / 97
# Points left:  827821
# Saved: Facility  3  /  10  rack  95 / 97
# Points left:  826598
# Saved: Facility  3  /  10  rack  96 / 97
# Points left:  821525
# Saved: Facility  3  /  10  rack  97 / 97
# Points left:  821525
# Saved general facility file
# Successful points load of  FoothHills_Calgary_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  60
# Saved: Facility  4  /  10  rack  1 / 60
# Points left:  999071
# Saved: Facility  4  /  10  rack  2 / 60
# Points left:  994733
# Saved: Facility  4  /  10  rack  3 / 60
# Points left:  990933
# Saved: Facility  4  /  10  rack  4 / 60
# Points left:  981128
# Saved: Facility  4  /  10  rack  5 / 60
# Points left:  974466
# Saved: Facility  4  /  10  rack  6 / 60
# Points left:  971175
# Saved: Facility  4  /  10  rack  7 / 60
# Points left:  970276
# Saved: Facility  4  /  10  rack  8 / 60
# Points left:  967390
# Saved: Facility  4  /  10  rack  9 / 60
# Points left:  961556
# Saved: Facility  4  /  10  rack  10 / 60
# Points left:  960254
# Saved: Facility  4  /  10  rack  11 / 60
# Points left:  959909
# Saved: Facility  4  /  10  rack  12 / 60
# Points left:  954614
# Saved: Facility  4  /  10  rack  13 / 60
# Points left:  942470
# Saved: Facility  4  /  10  rack  14 / 60
# Points left:  935605
# Saved: Facility  4  /  10  rack  15 / 60
# Points left:  931427
# Saved: Facility  4  /  10  rack  16 / 60
# Points left:  925122
# Saved: Facility  4  /  10  rack  17 / 60
# Points left:  923404
# Saved: Facility  4  /  10  rack  18 / 60
# Points left:  917201
# Saved: Facility  4  /  10  rack  19 / 60
# Points left:  904871
# Saved: Facility  4  /  10  rack  20 / 60
# Points left:  898789
# Saved: Facility  4  /  10  rack  21 / 60
# Points left:  891836
# Saved: Facility  4  /  10  rack  22 / 60
# Points left:  884830
# Saved: Facility  4  /  10  rack  23 / 60
# Points left:  876309
# Saved: Facility  4  /  10  rack  24 / 60
# Points left:  869567
# Saved: Facility  4  /  10  rack  25 / 60
# Points left:  866974
# Saved: Facility  4  /  10  rack  26 / 60
# Points left:  866471
# Saved: Facility  4  /  10  rack  27 / 60
# Points left:  865925
# Saved: Facility  4  /  10  rack  28 / 60
# Points left:  862338
# Saved: Facility  4  /  10  rack  29 / 60
# Points left:  860026
# Saved: Facility  4  /  10  rack  30 / 60
# Points left:  851575
# Saved: Facility  4  /  10  rack  31 / 60
# Points left:  847303
# Saved: Facility  4  /  10  rack  32 / 60
# Points left:  846507
# Saved: Facility  4  /  10  rack  33 / 60
# Points left:  838325
# Saved: Facility  4  /  10  rack  34 / 60
# Points left:  835520
# Saved: Facility  4  /  10  rack  35 / 60
# Points left:  827767
# Saved: Facility  4  /  10  rack  36 / 60
# Points left:  823561
# Saved: Facility  4  /  10  rack  37 / 60
# Points left:  823087
# Saved: Facility  4  /  10  rack  38 / 60
# Points left:  820008
# Saved: Facility  4  /  10  rack  39 / 60
# Points left:  816779
# Saved: Facility  4  /  10  rack  40 / 60
# Points left:  814448
# Saved: Facility  4  /  10  rack  41 / 60
# Points left:  810532
# Saved: Facility  4  /  10  rack  42 / 60
# Points left:  803323
# Saved: Facility  4  /  10  rack  43 / 60
# Points left:  800578
# Saved: Facility  4  /  10  rack  44 / 60
# Points left:  794881
# Saved: Facility  4  /  10  rack  45 / 60
# Points left:  791250
# Saved: Facility  4  /  10  rack  46 / 60
# Points left:  779923
# Saved: Facility  4  /  10  rack  47 / 60
# Points left:  776495
# Saved: Facility  4  /  10  rack  48 / 60
# Points left:  770282
# Saved: Facility  4  /  10  rack  49 / 60
# Points left:  765654
# Saved: Facility  4  /  10  rack  50 / 60
# Points left:  764390
# Saved: Facility  4  /  10  rack  51 / 60
# Points left:  759668
# Saved: Facility  4  /  10  rack  52 / 60
# Points left:  747929
# Saved: Facility  4  /  10  rack  53 / 60
# Points left:  739092
# Saved: Facility  4  /  10  rack  54 / 60
# Points left:  730944
# Saved: Facility  4  /  10  rack  55 / 60
# Points left:  724747
# Saved: Facility  4  /  10  rack  56 / 60
# Points left:  719526
# Saved: Facility  4  /  10  rack  57 / 60
# Points left:  719522
# Saved: Facility  4  /  10  rack  58 / 60
# Points left:  719410
# Saved: Facility  4  /  10  rack  59 / 60
# Points left:  718815
# Saved: Facility  4  /  10  rack  60 / 60
# Points left:  718745
# Saved general facility file
# Successful points load of  Lethbridge_1cm_nomals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  14
# Saved: Facility  5  /  10  rack  1 / 14
# Points left:  970889
# Saved: Facility  5  /  10  rack  2 / 14
# Points left:  968919
# Saved: Facility  5  /  10  rack  3 / 14
# Points left:  965249
# Saved: Facility  5  /  10  rack  4 / 14
# Points left:  955223
# Saved: Facility  5  /  10  rack  5 / 14
# Points left:  941353
# Saved: Facility  5  /  10  rack  6 / 14
# Points left:  922484
# Saved: Facility  5  /  10  rack  7 / 14
# Points left:  896969
# Saved: Facility  5  /  10  rack  8 / 14
# Points left:  868645
# Saved: Facility  5  /  10  rack  9 / 14
# Points left:  863170
# Saved: Facility  5  /  10  rack  10 / 14
# Points left:  853596
# Saved: Facility  5  /  10  rack  11 / 14
# Points left:  851897
# Saved: Facility  5  /  10  rack  12 / 14
# Points left:  849553
# Saved: Facility  5  /  10  rack  13 / 14
# Points left:  847952
# Saved: Facility  5  /  10  rack  14 / 14
# Points left:  845239
# Saved general facility file
# Successful points load of  edmontonNorth_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  34
# Saved: Facility  6  /  10  rack  1 / 34
# Points left:  993253
# Saved: Facility  6  /  10  rack  2 / 34
# Points left:  981243
# Saved: Facility  6  /  10  rack  3 / 34
# Points left:  974682
# Saved: Facility  6  /  10  rack  4 / 34
# Points left:  962904
# Saved: Facility  6  /  10  rack  5 / 34
# Points left:  950306
# Saved: Facility  6  /  10  rack  6 / 34
# Points left:  941753
# Saved: Facility  6  /  10  rack  7 / 34
# Points left:  941141
# Saved: Facility  6  /  10  rack  8 / 34
# Points left:  938094
# Saved: Facility  6  /  10  rack  9 / 34
# Points left:  930190
# Saved: Facility  6  /  10  rack  10 / 34
# Points left:  924895
# Saved: Facility  6  /  10  rack  11 / 34
# Points left:  916161
# Saved: Facility  6  /  10  rack  12 / 34
# Points left:  908198
# Saved: Facility  6  /  10  rack  13 / 34
# Points left:  904334
# Saved: Facility  6  /  10  rack  14 / 34
# Points left:  899666
# Saved: Facility  6  /  10  rack  15 / 34
# Points left:  887866
# Saved: Facility  6  /  10  rack  16 / 34
# Points left:  876728
# Saved: Facility  6  /  10  rack  17 / 34
# Points left:  866334
# Saved: Facility  6  /  10  rack  18 / 34
# Points left:  858174
# Saved: Facility  6  /  10  rack  19 / 34
# Points left:  846539
# Saved: Facility  6  /  10  rack  20 / 34
# Points left:  833502
# Saved: Facility  6  /  10  rack  21 / 34
# Points left:  824167
# Saved: Facility  6  /  10  rack  22 / 34
# Points left:  815648
# Saved: Facility  6  /  10  rack  23 / 34
# Points left:  803747
# Saved: Facility  6  /  10  rack  24 / 34
# Points left:  792032
# Saved: Facility  6  /  10  rack  25 / 34
# Points left:  783452
# Saved: Facility  6  /  10  rack  26 / 34
# Points left:  773991
# Saved: Facility  6  /  10  rack  27 / 34
# Points left:  759647
# Saved: Facility  6  /  10  rack  28 / 34
# Points left:  746800
# Saved: Facility  6  /  10  rack  29 / 34
# Points left:  729133
# Saved: Facility  6  /  10  rack  30 / 34
# Points left:  728836
# Saved: Facility  6  /  10  rack  31 / 34
# Points left:  728213
# Saved: Facility  6  /  10  rack  32 / 34
# Points left:  725354
# Saved: Facility  6  /  10  rack  33 / 34
# Points left:  722364
# Saved: Facility  6  /  10  rack  34 / 34
# Points left:  718093
# Saved general facility file
# Successful points load of  Dawson_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  150
# Saved: Facility  7  /  10  rack  1 / 150
# Points left:  997235
# Saved: Facility  7  /  10  rack  2 / 150
# Points left:  992706
# Saved: Facility  7  /  10  rack  3 / 150
# Points left:  987023
# Saved: Facility  7  /  10  rack  4 / 150
# Points left:  983863
# Saved: Facility  7  /  10  rack  5 / 150
# Points left:  983128
# Saved: Facility  7  /  10  rack  6 / 150
# Points left:  982795
# Saved: Facility  7  /  10  rack  7 / 150
# Points left:  979880
# Saved: Facility  7  /  10  rack  8 / 150
# Points left:  975171
# Saved: Facility  7  /  10  rack  9 / 150
# Points left:  972569
# Saved: Facility  7  /  10  rack  10 / 150
# Points left:  969625
# Saved: Facility  7  /  10  rack  11 / 150
# Points left:  966621
# Saved: Facility  7  /  10  rack  12 / 150
# Points left:  965463
# Saved: Facility  7  /  10  rack  13 / 150
# Points left:  961977
# Saved: Facility  7  /  10  rack  14 / 150
# Points left:  958082
# Saved: Facility  7  /  10  rack  15 / 150
# Points left:  953642
# Saved: Facility  7  /  10  rack  16 / 150
# Points left:  951225
# Saved: Facility  7  /  10  rack  17 / 150
# Points left:  950931
# Saved: Facility  7  /  10  rack  18 / 150
# Points left:  950931
# Saved: Facility  7  /  10  rack  19 / 150
# Points left:  950636
# Saved: Facility  7  /  10  rack  20 / 150
# Points left:  949399
# Saved: Facility  7  /  10  rack  21 / 150
# Points left:  948115
# Saved: Facility  7  /  10  rack  22 / 150
# Points left:  947808
# Saved: Facility  7  /  10  rack  23 / 150
# Points left:  947682
# Saved: Facility  7  /  10  rack  24 / 150
# Points left:  947367
# Saved: Facility  7  /  10  rack  25 / 150
# Points left:  947198
# Saved: Facility  7  /  10  rack  26 / 150
# Points left:  947198
# Saved: Facility  7  /  10  rack  27 / 150
# Points left:  947198
# Saved: Facility  7  /  10  rack  28 / 150
# Points left:  947198
# Saved: Facility  7  /  10  rack  29 / 150
# Points left:  946870
# Saved: Facility  7  /  10  rack  30 / 150
# Points left:  945830
# Saved: Facility  7  /  10  rack  31 / 150
# Points left:  945830
# Saved: Facility  7  /  10  rack  32 / 150
# Points left:  945047
# Saved: Facility  7  /  10  rack  33 / 150
# Points left:  944819
# Saved: Facility  7  /  10  rack  34 / 150
# Points left:  944818
# Saved: Facility  7  /  10  rack  35 / 150
# Points left:  943163
# Saved: Facility  7  /  10  rack  36 / 150
# Points left:  940831
# Saved: Facility  7  /  10  rack  37 / 150
# Points left:  938951
# Saved: Facility  7  /  10  rack  38 / 150
# Points left:  936567
# Saved: Facility  7  /  10  rack  39 / 150
# Points left:  935713
# Saved: Facility  7  /  10  rack  40 / 150
# Points left:  934709
# Saved: Facility  7  /  10  rack  41 / 150
# Points left:  933949
# Saved: Facility  7  /  10  rack  42 / 150
# Points left:  933738
# Saved: Facility  7  /  10  rack  43 / 150
# Points left:  932649
# Saved: Facility  7  /  10  rack  44 / 150
# Points left:  931763
# Saved: Facility  7  /  10  rack  45 / 150
# Points left:  930337
# Saved: Facility  7  /  10  rack  46 / 150
# Points left:  929573
# Saved: Facility  7  /  10  rack  47 / 150
# Points left:  929504
# Saved: Facility  7  /  10  rack  48 / 150
# Points left:  928179
# Saved: Facility  7  /  10  rack  49 / 150
# Points left:  926588
# Saved: Facility  7  /  10  rack  50 / 150
# Points left:  925790
# Saved: Facility  7  /  10  rack  51 / 150
# Points left:  924831
# Saved: Facility  7  /  10  rack  52 / 150
# Points left:  923785
# Saved: Facility  7  /  10  rack  53 / 150
# Points left:  922695
# Saved: Facility  7  /  10  rack  54 / 150
# Points left:  918256
# Saved: Facility  7  /  10  rack  55 / 150
# Points left:  917897
# Saved: Facility  7  /  10  rack  56 / 150
# Points left:  917639
# Saved: Facility  7  /  10  rack  57 / 150
# Points left:  917459
# Saved: Facility  7  /  10  rack  58 / 150
# Points left:  917003
# Saved: Facility  7  /  10  rack  59 / 150
# Points left:  914129
# Saved: Facility  7  /  10  rack  60 / 150
# Points left:  913357
# Saved: Facility  7  /  10  rack  61 / 150
# Points left:  911517
# Saved: Facility  7  /  10  rack  62 / 150
# Points left:  907654
# Saved: Facility  7  /  10  rack  63 / 150
# Points left:  905981
# Saved: Facility  7  /  10  rack  64 / 150
# Points left:  905767
# Saved: Facility  7  /  10  rack  65 / 150
# Points left:  903230
# Saved: Facility  7  /  10  rack  66 / 150
# Points left:  902673
# Saved: Facility  7  /  10  rack  67 / 150
# Points left:  899061
# Saved: Facility  7  /  10  rack  68 / 150
# Points left:  898457
# Saved: Facility  7  /  10  rack  69 / 150
# Points left:  896427
# Saved: Facility  7  /  10  rack  70 / 150
# Points left:  894865
# Saved: Facility  7  /  10  rack  71 / 150
# Points left:  893189
# Saved: Facility  7  /  10  rack  72 / 150
# Points left:  891053
# Saved: Facility  7  /  10  rack  73 / 150
# Points left:  889876
# Saved: Facility  7  /  10  rack  74 / 150
# Points left:  888712
# Saved: Facility  7  /  10  rack  75 / 150
# Points left:  886329
# Saved: Facility  7  /  10  rack  76 / 150
# Points left:  884984
# Saved: Facility  7  /  10  rack  77 / 150
# Points left:  883755
# Saved: Facility  7  /  10  rack  78 / 150
# Points left:  883649
# Saved: Facility  7  /  10  rack  79 / 150
# Points left:  881138
# Saved: Facility  7  /  10  rack  80 / 150
# Points left:  880850
# Saved: Facility  7  /  10  rack  81 / 150
# Points left:  878536
# Saved: Facility  7  /  10  rack  82 / 150
# Points left:  877572
# Saved: Facility  7  /  10  rack  83 / 150
# Points left:  875958
# Saved: Facility  7  /  10  rack  84 / 150
# Points left:  875731
# Saved: Facility  7  /  10  rack  85 / 150
# Points left:  874125
# Saved: Facility  7  /  10  rack  86 / 150
# Points left:  872360
# Saved: Facility  7  /  10  rack  87 / 150
# Points left:  868101
# Saved: Facility  7  /  10  rack  88 / 150
# Points left:  866032
# Saved: Facility  7  /  10  rack  89 / 150
# Points left:  863488
# Saved: Facility  7  /  10  rack  90 / 150
# Points left:  862018
# Saved: Facility  7  /  10  rack  91 / 150
# Points left:  861379
# Saved: Facility  7  /  10  rack  92 / 150
# Points left:  859549
# Saved: Facility  7  /  10  rack  93 / 150
# Points left:  856766
# Saved: Facility  7  /  10  rack  94 / 150
# Points left:  855061
# Saved: Facility  7  /  10  rack  95 / 150
# Points left:  853626
# Saved: Facility  7  /  10  rack  96 / 150
# Points left:  850599
# Saved: Facility  7  /  10  rack  97 / 150
# Points left:  849385
# Saved: Facility  7  /  10  rack  98 / 150
# Points left:  848618
# Saved: Facility  7  /  10  rack  99 / 150
# Points left:  847247
# Saved: Facility  7  /  10  rack  100 / 150
# Points left:  845427
# Saved: Facility  7  /  10  rack  101 / 150
# Points left:  843455
# Saved: Facility  7  /  10  rack  102 / 150
# Points left:  842693
# Saved: Facility  7  /  10  rack  103 / 150
# Points left:  841960
# Saved: Facility  7  /  10  rack  104 / 150
# Points left:  839128
# Saved: Facility  7  /  10  rack  105 / 150
# Points left:  837645
# Saved: Facility  7  /  10  rack  106 / 150
# Points left:  836762
# Saved: Facility  7  /  10  rack  107 / 150
# Points left:  834223
# Saved: Facility  7  /  10  rack  108 / 150
# Points left:  833050
# Saved: Facility  7  /  10  rack  109 / 150
# Points left:  831057
# Saved: Facility  7  /  10  rack  110 / 150
# Points left:  829679
# Saved: Facility  7  /  10  rack  111 / 150
# Points left:  828508
# Saved: Facility  7  /  10  rack  112 / 150
# Points left:  827064
# Saved: Facility  7  /  10  rack  113 / 150
# Points left:  824446
# Saved: Facility  7  /  10  rack  114 / 150
# Points left:  822676
# Saved: Facility  7  /  10  rack  115 / 150
# Points left:  821008
# Saved: Facility  7  /  10  rack  116 / 150
# Points left:  820774
# Saved: Facility  7  /  10  rack  117 / 150
# Points left:  820280
# Saved: Facility  7  /  10  rack  118 / 150
# Points left:  816919
# Saved: Facility  7  /  10  rack  119 / 150
# Points left:  816630
# Saved: Facility  7  /  10  rack  120 / 150
# Points left:  814341
# Saved: Facility  7  /  10  rack  121 / 150
# Points left:  813393
# Saved: Facility  7  /  10  rack  122 / 150
# Points left:  811387
# Saved: Facility  7  /  10  rack  123 / 150
# Points left:  810152
# Saved: Facility  7  /  10  rack  124 / 150
# Points left:  808472
# Saved: Facility  7  /  10  rack  125 / 150
# Points left:  807637
# Saved: Facility  7  /  10  rack  126 / 150
# Points left:  806965
# Saved: Facility  7  /  10  rack  127 / 150
# Points left:  805858
# Saved: Facility  7  /  10  rack  128 / 150
# Points left:  803958
# Saved: Facility  7  /  10  rack  129 / 150
# Points left:  803717
# Saved: Facility  7  /  10  rack  130 / 150
# Points left:  801075
# Saved: Facility  7  /  10  rack  131 / 150
# Points left:  799413
# Saved: Facility  7  /  10  rack  132 / 150
# Points left:  798011
# Saved: Facility  7  /  10  rack  133 / 150
# Points left:  794226
# Saved: Facility  7  /  10  rack  134 / 150
# Points left:  792953
# Saved: Facility  7  /  10  rack  135 / 150
# Points left:  790774
# Saved: Facility  7  /  10  rack  136 / 150
# Points left:  789267
# Saved: Facility  7  /  10  rack  137 / 150
# Points left:  787686
# Saved: Facility  7  /  10  rack  138 / 150
# Points left:  787099
# Saved: Facility  7  /  10  rack  139 / 150
# Points left:  784873
# Saved: Facility  7  /  10  rack  140 / 150
# Points left:  782672
# Saved: Facility  7  /  10  rack  141 / 150
# Points left:  781613
# Saved: Facility  7  /  10  rack  142 / 150
# Points left:  778824
# Saved: Facility  7  /  10  rack  143 / 150
# Points left:  777871
# Saved: Facility  7  /  10  rack  144 / 150
# Points left:  777136
# Saved: Facility  7  /  10  rack  145 / 150
# Points left:  774383
# Saved: Facility  7  /  10  rack  146 / 150
# Points left:  772765
# Saved: Facility  7  /  10  rack  147 / 150
# Points left:  768402
# Saved: Facility  7  /  10  rack  148 / 150
# Points left:  767580
# Saved: Facility  7  /  10  rack  149 / 150
# Points left:  766196
# Saved: Facility  7  /  10  rack  150 / 150
# Points left:  763990
# Saved general facility file
# Successful points load of  StFrancois_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  63
# Saved: Facility  8  /  10  rack  1 / 63
# Points left:  997239
# Saved: Facility  8  /  10  rack  2 / 63
# Points left:  996182
# Saved: Facility  8  /  10  rack  3 / 63
# Points left:  992990
# Saved: Facility  8  /  10  rack  4 / 63
# Points left:  990128
# Saved: Facility  8  /  10  rack  5 / 63
# Points left:  987664
# Saved: Facility  8  /  10  rack  6 / 63
# Points left:  985310
# Saved: Facility  8  /  10  rack  7 / 63
# Points left:  979999
# Saved: Facility  8  /  10  rack  8 / 63
# Points left:  976475
# Saved: Facility  8  /  10  rack  9 / 63
# Points left:  973356
# Saved: Facility  8  /  10  rack  10 / 63
# Points left:  968440
# Saved: Facility  8  /  10  rack  11 / 63
# Points left:  966379
# Saved: Facility  8  /  10  rack  12 / 63
# Points left:  963932
# Saved: Facility  8  /  10  rack  13 / 63
# Points left:  963897
# Saved: Facility  8  /  10  rack  14 / 63
# Points left:  960986
# Saved: Facility  8  /  10  rack  15 / 63
# Points left:  957481
# Saved: Facility  8  /  10  rack  16 / 63
# Points left:  956298
# Saved: Facility  8  /  10  rack  17 / 63
# Points left:  953567
# Saved: Facility  8  /  10  rack  18 / 63
# Points left:  949723
# Saved: Facility  8  /  10  rack  19 / 63
# Points left:  947865
# Saved: Facility  8  /  10  rack  20 / 63
# Points left:  945435
# Saved: Facility  8  /  10  rack  21 / 63
# Points left:  944022
# Saved: Facility  8  /  10  rack  22 / 63
# Points left:  941320
# Saved: Facility  8  /  10  rack  23 / 63
# Points left:  939542
# Saved: Facility  8  /  10  rack  24 / 63
# Points left:  935435
# Saved: Facility  8  /  10  rack  25 / 63
# Points left:  932445
# Saved: Facility  8  /  10  rack  26 / 63
# Points left:  930390
# Saved: Facility  8  /  10  rack  27 / 63
# Points left:  927996
# Saved: Facility  8  /  10  rack  28 / 63
# Points left:  923501
# Saved: Facility  8  /  10  rack  29 / 63
# Points left:  922000
# Saved: Facility  8  /  10  rack  30 / 63
# Points left:  917479
# Saved: Facility  8  /  10  rack  31 / 63
# Points left:  909127
# Saved: Facility  8  /  10  rack  32 / 63
# Points left:  904622
# Saved: Facility  8  /  10  rack  33 / 63
# Points left:  900225
# Saved: Facility  8  /  10  rack  34 / 63
# Points left:  897232
# Saved: Facility  8  /  10  rack  35 / 63
# Points left:  889169
# Saved: Facility  8  /  10  rack  36 / 63
# Points left:  882860
# Saved: Facility  8  /  10  rack  37 / 63
# Points left:  880091
# Saved: Facility  8  /  10  rack  38 / 63
# Points left:  877295
# Saved: Facility  8  /  10  rack  39 / 63
# Points left:  870244
# Saved: Facility  8  /  10  rack  40 / 63
# Points left:  867329
# Saved: Facility  8  /  10  rack  41 / 63
# Points left:  863353
# Saved: Facility  8  /  10  rack  42 / 63
# Points left:  858440
# Saved: Facility  8  /  10  rack  43 / 63
# Points left:  854485
# Saved: Facility  8  /  10  rack  44 / 63
# Points left:  850159
# Saved: Facility  8  /  10  rack  45 / 63
# Points left:  850068
# Saved: Facility  8  /  10  rack  46 / 63
# Points left:  845103
# Saved: Facility  8  /  10  rack  47 / 63
# Points left:  843398
# Saved: Facility  8  /  10  rack  48 / 63
# Points left:  838975
# Saved: Facility  8  /  10  rack  49 / 63
# Points left:  838870
# Saved: Facility  8  /  10  rack  50 / 63
# Points left:  836216
# Saved: Facility  8  /  10  rack  51 / 63
# Points left:  832414
# Saved: Facility  8  /  10  rack  52 / 63
# Points left:  828707
# Saved: Facility  8  /  10  rack  53 / 63
# Points left:  827138
# Saved: Facility  8  /  10  rack  54 / 63
# Points left:  825039
# Saved: Facility  8  /  10  rack  55 / 63
# Points left:  822745
# Saved: Facility  8  /  10  rack  56 / 63
# Points left:  819117
# Saved: Facility  8  /  10  rack  57 / 63
# Points left:  818951
# Saved: Facility  8  /  10  rack  58 / 63
# Points left:  816245
# Saved: Facility  8  /  10  rack  59 / 63
# Points left:  812174
# Saved: Facility  8  /  10  rack  60 / 63
# Points left:  809477
# Saved: Facility  8  /  10  rack  61 / 63
# Points left:  805122
# Saved: Facility  8  /  10  rack  62 / 63
# Points left:  802141
# Saved: Facility  8  /  10  rack  63 / 63
# Points left:  800594
# Saved general facility file
# Successful points load of  bramptonWalker_1cm_normals.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  116
# Saved: Facility  9  /  10  rack  1 / 116
# Points left:  998741
# Saved: Facility  9  /  10  rack  2 / 116
# Points left:  997526
# Saved: Facility  9  /  10  rack  3 / 116
# Points left:  997110
# Saved: Facility  9  /  10  rack  4 / 116
# Points left:  996314
# Saved: Facility  9  /  10  rack  5 / 116
# Points left:  996314
# Saved: Facility  9  /  10  rack  6 / 116
# Points left:  996314
# Saved: Facility  9  /  10  rack  7 / 116
# Points left:  996314
# Saved: Facility  9  /  10  rack  8 / 116
# Points left:  994441
# Saved: Facility  9  /  10  rack  9 / 116
# Points left:  994441
# Saved: Facility  9  /  10  rack  10 / 116
# Points left:  991571
# Saved: Facility  9  /  10  rack  11 / 116
# Points left:  991571
# Saved: Facility  9  /  10  rack  12 / 116
# Points left:  988802
# Saved: Facility  9  /  10  rack  13 / 116
# Points left:  986760
# Saved: Facility  9  /  10  rack  14 / 116
# Points left:  986458
# Saved: Facility  9  /  10  rack  15 / 116
# Points left:  986458
# Saved: Facility  9  /  10  rack  16 / 116
# Points left:  986458
# Saved: Facility  9  /  10  rack  17 / 116
# Points left:  975884
# Saved: Facility  9  /  10  rack  18 / 116
# Points left:  973913
# Saved: Facility  9  /  10  rack  19 / 116
# Points left:  973913
# Saved: Facility  9  /  10  rack  20 / 116
# Points left:  973913
# Saved: Facility  9  /  10  rack  21 / 116
# Points left:  972193
# Saved: Facility  9  /  10  rack  22 / 116
# Points left:  969026
# Saved: Facility  9  /  10  rack  23 / 116
# Points left:  967505
# Saved: Facility  9  /  10  rack  24 / 116
# Points left:  967212
# Saved: Facility  9  /  10  rack  25 / 116
# Points left:  965744
# Saved: Facility  9  /  10  rack  26 / 116
# Points left:  964943
# Saved: Facility  9  /  10  rack  27 / 116
# Points left:  958126
# Saved: Facility  9  /  10  rack  28 / 116
# Points left:  955673
# Saved: Facility  9  /  10  rack  29 / 116
# Points left:  955673
# Saved: Facility  9  /  10  rack  30 / 116
# Points left:  955106
# Saved: Facility  9  /  10  rack  31 / 116
# Points left:  953347
# Saved: Facility  9  /  10  rack  32 / 116
# Points left:  949904
# Saved: Facility  9  /  10  rack  33 / 116
# Points left:  946217
# Saved: Facility  9  /  10  rack  34 / 116
# Points left:  946217
# Saved: Facility  9  /  10  rack  35 / 116
# Points left:  946217
# Saved: Facility  9  /  10  rack  36 / 116
# Points left:  946217
# Saved: Facility  9  /  10  rack  37 / 116
# Points left:  943899
# Saved: Facility  9  /  10  rack  38 / 116
# Points left:  943899
# Saved: Facility  9  /  10  rack  39 / 116
# Points left:  942655
# Saved: Facility  9  /  10  rack  40 / 116
# Points left:  941478
# Saved: Facility  9  /  10  rack  41 / 116
# Points left:  941478
# Saved: Facility  9  /  10  rack  42 / 116
# Points left:  939280
# Saved: Facility  9  /  10  rack  43 / 116
# Points left:  939280
# Saved: Facility  9  /  10  rack  44 / 116
# Points left:  938398
# Saved: Facility  9  /  10  rack  45 / 116
# Points left:  937547
# Saved: Facility  9  /  10  rack  46 / 116
# Points left:  936305
# Saved: Facility  9  /  10  rack  47 / 116
# Points left:  936305
# Saved: Facility  9  /  10  rack  48 / 116
# Points left:  934425
# Saved: Facility  9  /  10  rack  49 / 116
# Points left:  930921
# Saved: Facility  9  /  10  rack  50 / 116
# Points left:  929492
# Saved: Facility  9  /  10  rack  51 / 116
# Points left:  927394
# Saved: Facility  9  /  10  rack  52 / 116
# Points left:  926345
# Saved: Facility  9  /  10  rack  53 / 116
# Points left:  926345
# Saved: Facility  9  /  10  rack  54 / 116
# Points left:  925165
# Saved: Facility  9  /  10  rack  55 / 116
# Points left:  925165
# Saved: Facility  9  /  10  rack  56 / 116
# Points left:  924806
# Saved: Facility  9  /  10  rack  57 / 116
# Points left:  924806
# Saved: Facility  9  /  10  rack  58 / 116
# Points left:  922905
# Saved: Facility  9  /  10  rack  59 / 116
# Points left:  922905
# Saved: Facility  9  /  10  rack  60 / 116
# Points left:  922722
# Saved: Facility  9  /  10  rack  61 / 116
# Points left:  920558
# Saved: Facility  9  /  10  rack  62 / 116
# Points left:  920558
# Saved: Facility  9  /  10  rack  63 / 116
# Points left:  918045
# Saved: Facility  9  /  10  rack  64 / 116
# Points left:  917010
# Saved: Facility  9  /  10  rack  65 / 116
# Points left:  915844
# Saved: Facility  9  /  10  rack  66 / 116
# Points left:  914238
# Saved: Facility  9  /  10  rack  67 / 116
# Points left:  911057
# Saved: Facility  9  /  10  rack  68 / 116
# Points left:  910689
# Saved: Facility  9  /  10  rack  69 / 116
# Points left:  910689
# Saved: Facility  9  /  10  rack  70 / 116
# Points left:  906056
# Saved: Facility  9  /  10  rack  71 / 116
# Points left:  904997
# Saved: Facility  9  /  10  rack  72 / 116
# Points left:  902932
# Saved: Facility  9  /  10  rack  73 / 116
# Points left:  895897
# Saved: Facility  9  /  10  rack  74 / 116
# Points left:  895622
# Saved: Facility  9  /  10  rack  75 / 116
# Points left:  893605
# Saved: Facility  9  /  10  rack  76 / 116
# Points left:  892606
# Saved: Facility  9  /  10  rack  77 / 116
# Points left:  891378
# Saved: Facility  9  /  10  rack  78 / 116
# Points left:  887975
# Saved: Facility  9  /  10  rack  79 / 116
# Points left:  885272
# Saved: Facility  9  /  10  rack  80 / 116
# Points left:  885272
# Saved: Facility  9  /  10  rack  81 / 116
# Points left:  881485
# Saved: Facility  9  /  10  rack  82 / 116
# Points left:  878070
# Saved: Facility  9  /  10  rack  83 / 116
# Points left:  874925
# Saved: Facility  9  /  10  rack  84 / 116
# Points left:  873760
# Saved: Facility  9  /  10  rack  85 / 116
# Points left:  871646
# Saved: Facility  9  /  10  rack  86 / 116
# Points left:  871213
# Saved: Facility  9  /  10  rack  87 / 116
# Points left:  870046
# Saved: Facility  9  /  10  rack  88 / 116
# Points left:  867590
# Saved: Facility  9  /  10  rack  89 / 116
# Points left:  867590
# Saved: Facility  9  /  10  rack  90 / 116
# Points left:  867030
# Saved: Facility  9  /  10  rack  91 / 116
# Points left:  864070
# Saved: Facility  9  /  10  rack  92 / 116
# Points left:  864070
# Saved: Facility  9  /  10  rack  93 / 116
# Points left:  864070
# Saved: Facility  9  /  10  rack  94 / 116
# Points left:  864070
# Saved: Facility  9  /  10  rack  95 / 116
# Points left:  861265
# Saved: Facility  9  /  10  rack  96 / 116
# Points left:  859313
# Saved: Facility  9  /  10  rack  97 / 116
# Points left:  856781
# Saved: Facility  9  /  10  rack  98 / 116
# Points left:  856437
# Saved: Facility  9  /  10  rack  99 / 116
# Points left:  854050
# Saved: Facility  9  /  10  rack  100 / 116
# Points left:  854050
# Saved: Facility  9  /  10  rack  101 / 116
# Points left:  851729
# Saved: Facility  9  /  10  rack  102 / 116
# Points left:  851103
# Saved: Facility  9  /  10  rack  103 / 116
# Points left:  846055
# Saved: Facility  9  /  10  rack  104 / 116
# Points left:  843873
# Saved: Facility  9  /  10  rack  105 / 116
# Points left:  842630
# Saved: Facility  9  /  10  rack  106 / 116
# Points left:  842630
# Saved: Facility  9  /  10  rack  107 / 116
# Points left:  838267
# Saved: Facility  9  /  10  rack  108 / 116
# Points left:  838267
# Saved: Facility  9  /  10  rack  109 / 116
# Points left:  835655
# Saved: Facility  9  /  10  rack  110 / 116
# Points left:  834511
# Saved: Facility  9  /  10  rack  111 / 116
# Points left:  834390
# Saved: Facility  9  /  10  rack  112 / 116
# Points left:  830806
# Saved: Facility  9  /  10  rack  113 / 116
# Points left:  829808
# Saved: Facility  9  /  10  rack  114 / 116
# Points left:  829808
# Saved: Facility  9  /  10  rack  115 / 116
# Points left:  829286
# Saved: Facility  9  /  10  rack  116 / 116
# Points left:  826464
# Saved general facility file
# Successful points load of  CoteDeLiesse_normals_1cm.laz
# Calculating normals for scan file...
# Normals calculation done!
# Facility's rack count:  58
# Saved: Facility  10  /  10  rack  1 / 58
# Points left:  996405
# Saved: Facility  10  /  10  rack  2 / 58
# Points left:  988964
# Saved: Facility  10  /  10  rack  3 / 58
# Points left:  977078
# Saved: Facility  10  /  10  rack  4 / 58
# Points left:  974663
# Saved: Facility  10  /  10  rack  5 / 58
# Points left:  970305
# Saved: Facility  10  /  10  rack  6 / 58
# Points left:  967392
# Saved: Facility  10  /  10  rack  7 / 58
# Points left:  957786
# Saved: Facility  10  /  10  rack  8 / 58
# Points left:  950509
# Saved: Facility  10  /  10  rack  9 / 58
# Points left:  950241
# Saved: Facility  10  /  10  rack  10 / 58
# Points left:  945056
# Saved: Facility  10  /  10  rack  11 / 58
# Points left:  944828
# Saved: Facility  10  /  10  rack  12 / 58
# Points left:  940792
# Saved: Facility  10  /  10  rack  13 / 58
# Points left:  924396
# Saved: Facility  10  /  10  rack  14 / 58
# Points left:  924238
# Saved: Facility  10  /  10  rack  15 / 58
# Points left:  912588
# Saved: Facility  10  /  10  rack  16 / 58
# Points left:  907836
# Saved: Facility  10  /  10  rack  17 / 58
# Points left:  902520
# Saved: Facility  10  /  10  rack  18 / 58
# Points left:  891644
# Saved: Facility  10  /  10  rack  19 / 58
# Points left:  884322
# Saved: Facility  10  /  10  rack  20 / 58
# Points left:  884135
# Saved: Facility  10  /  10  rack  21 / 58
# Points left:  870808
# Saved: Facility  10  /  10  rack  22 / 58
# Points left:  864803
# Saved: Facility  10  /  10  rack  23 / 58
# Points left:  856950
# Saved: Facility  10  /  10  rack  24 / 58
# Points left:  853612
# Saved: Facility  10  /  10  rack  25 / 58
# Points left:  847857
# Saved: Facility  10  /  10  rack  26 / 58
# Points left:  843011
# Saved: Facility  10  /  10  rack  27 / 58
# Points left:  835080
# Saved: Facility  10  /  10  rack  28 / 58
# Points left:  832741
# Saved: Facility  10  /  10  rack  29 / 58
# Points left:  832627
# Saved: Facility  10  /  10  rack  30 / 58
# Points left:  822265
# Saved: Facility  10  /  10  rack  31 / 58
# Points left:  817551
# Saved: Facility  10  /  10  rack  32 / 58
# Points left:  811408
# Saved: Facility  10  /  10  rack  33 / 58
# Points left:  806090
# Saved: Facility  10  /  10  rack  34 / 58
# Points left:  802767
# Saved: Facility  10  /  10  rack  35 / 58
# Points left:  796371
# Saved: Facility  10  /  10  rack  36 / 58
# Points left:  796301
# Saved: Facility  10  /  10  rack  37 / 58
# Points left:  793837
# Saved: Facility  10  /  10  rack  38 / 58
# Points left:  793556
# Saved: Facility  10  /  10  rack  39 / 58
# Points left:  793429
# Saved: Facility  10  /  10  rack  40 / 58
# Points left:  782775
# Saved: Facility  10  /  10  rack  41 / 58
# Points left:  782386
# Saved: Facility  10  /  10  rack  42 / 58
# Points left:  775569
# Saved: Facility  10  /  10  rack  43 / 58
# Points left:  773445
# Saved: Facility  10  /  10  rack  44 / 58
# Points left:  773290
# Saved: Facility  10  /  10  rack  45 / 58
# Points left:  768437
# Saved: Facility  10  /  10  rack  46 / 58
# Points left:  765066
# Saved: Facility  10  /  10  rack  47 / 58
# Points left:  762930
# Saved: Facility  10  /  10  rack  48 / 58
# Points left:  758157
# Saved: Facility  10  /  10  rack  49 / 58
# Points left:  751912
# Saved: Facility  10  /  10  rack  50 / 58
# Points left:  751704
# Saved: Facility  10  /  10  rack  51 / 58
# Points left:  750616
# Saved: Facility  10  /  10  rack  52 / 58
# Points left:  750009
# Saved: Facility  10  /  10  rack  53 / 58
# Points left:  747124
# Saved: Facility  10  /  10  rack  54 / 58
# Points left:  746626
# Saved: Facility  10  /  10  rack  55 / 58
# Points left:  744490
# Saved: Facility  10  /  10  rack  56 / 58
# Points left:  742539
# Saved: Facility  10  /  10  rack  57 / 58
# Points left:  739880
# Saved: Facility  10  /  10  rack  58 / 58
# Points left:  738853
# Saved general facility file

# %% [markdown]
# Create the whole dataset of facilities racks dictionary in orther to divide them into 5 different areas of facilities of as equally as possible numbers of different rack types. This will promote a better balanced dataset of the data to train and test.

# %%
def create_facility_sets(facility_dict):
    # Create a dictionary to store the total count of objects for each object type across all facilities
    object_type_counts = defaultdict(int)
    
    # Calculate the total count of objects for each object type across all facilities
    for inner_dict in facility_dict.values():
        for obj_type, objects in inner_dict.items():
            object_type_counts[obj_type] += len(objects)
    
    # Sort the facilities based on the difference in object type counts compared to the average count
    average_counts = {obj_type: count / len(facility_dict) for obj_type, count in object_type_counts.items()}
    sorted_facilities = sorted(facility_dict, key=lambda facility: sum(abs(len(objects) - average_counts[obj_type]) for obj_type, objects in facility_dict[facility].items()))
    
    # Divide the sorted facilities into five sets
    facility_sets = [[] for _ in range(5)]
    set_index = 0
    for facility in sorted_facilities:
        facility_sets[set_index].append(facility)
        set_index = (set_index + 1) % 5
    
    # Print each set with their facilities and object type counts
    for i, facility_set in enumerate(facility_sets, start=1):
        print(f"Set {i}:")
        for facility in facility_set:
            object_types = facility_dict[facility]
            object_type_counts = {obj_type: len(objects) for obj_type, objects in object_types.items()}
            print(f"  Facility {facility}: {object_type_counts}")

# %%
create_facility_sets(facility_racks_dict)
# Out:
# Set 1:
#   Facility 196524856938_CAN - QC, Montreal - 5757 Chemin St. Francois: {'select_rack': 58, 'suspended_rack': 1}
#   Facility 153924853363_US - TX, El Paso - Railroad: {'drive_in_rack': 23, 'select_rack': 55, 'gravity_feed_rack': 1}
# Set 2:
#   Facility 194913221226_CAN - AB, Calgary - 5555 78th Ave SE (Calgary Foothills): {'select_rack': 56, 'suspended_rack': 1}
#   Facility 142728079488_US - CA, Los Angeles - Los Palos (Big Bear): {'select_rack': 86}
# Set 3:
#   Facility 143039459344_US - NJ, Logan Township - Crossroads: {'select_rack': 52}
#   Facility 194916756196_CAN - AB, Edmonton - 12536 62 St (Northlands): {'select_rack': 29, 'suspended_rack': 2, 'drive_in_rack': 3}
# Set 4:
#   Facility 196527859613_CAN - QC, Saint-Laurent - 6100 Côte de Liesse: {'select_rack': 43, 'suspended_rack': 3, 'gravity_feed_rack': 6}
#   Facility 194915139195_CAN - AB, Lethbridge - 585 41st St North: {'select_rack': 10, 'drive_in_rack': 4}
# Set 5:
#   Facility 196527723206_CAN - ON, Brampton - 107 Walker Dr: {'select_rack': 82}
#   Facility 196524033787_CAN - MB, Winnipeg - 200 Dawson Rd N: {'gravity_feed_rack': 16, 'drive_in_rack': 10, 'select_rack': 113}

# %% [markdown]
# Print some useful statistics of racks

# %%
def calculate_total_counts(facility_dict):
    total_counts = defaultdict(int)
    
    for inner_dict in facility_dict.values():
        for obj_type, objects in inner_dict.items():
            total_counts[obj_type] += len(objects)
    
    return total_counts

# %%
total_counts = calculate_total_counts(facility_racks_dict)

# %%
# Print the total counts
for obj_type, count in total_counts.items():
    print(f"{obj_type}: {count}")
# Out:
# select_rack: 584
# drive_in_rack: 40
# gravity_feed_rack: 23
# suspended_rack: 7
